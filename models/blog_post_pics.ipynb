# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
housing_data1 = pd.read_csv('kc_house_data.csv')
housing_data1.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0         NaN   0.0     ...          7        1180
# 1      7242     2.0         0.0   0.0     ...          7        2170
# 2     10000     1.0         0.0   0.0     ...          6         770
# 3      5000     1.0         0.0   0.0     ...          7        1050
# 4      8080     1.0         0.0   0.0     ...          8        1680
#
#    sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
housing_data1 = housing_data1.dropna()
housing_data1 = housing_data1.drop(columns=['lat', 'long', 'yr_renovated', 'view','id', 'zipcode', 'waterfront', 'sqft_basement'])

# %%
housing_data1.head()
# Out:
#         date      price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 1  12/9/2014   538000.0         3       2.25         2570      7242     2.0
# 3  12/9/2014   604000.0         4       3.00         1960      5000     1.0
# 4  2/18/2015   510000.0         3       2.00         1680      8080     1.0
# 5  5/12/2014  1230000.0         4       4.50         5420    101930     1.0
# 6  6/27/2014   257500.0         3       2.25         1715      6819     2.0
#
#    condition  grade  sqft_above  yr_built  sqft_living15  sqft_lot15
# 1          3      7        2170      1951           1690        7639
# 3          5      7        1050      1965           1360        5000
# 4          3      8        1680      1987           1800        7503
# 5          3     11        3890      2001           4760      101930
# 6          3      7        1715      1995           2238        6819

# %%
sns.set(style="white")

# Create a covariance matrix
corr = housing_data1.corr()

# Generate a mask the size of our covariance matrix
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11,9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220,10,as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr,mask=mask,cmap=cmap,vmax=1,center=0,square=True, 
            linewidth=.5, cbar_kws={'shrink': .5})

ax.set_title('Multi-Collinearity of Features')
plt.savefig('correlation2.png')

# %%
housing_data = pd.read_csv('kc_house_data.csv')

# %%
housing_data = housing_data[['price', 'bedrooms', 'sqft_living', 'waterfront', 'condition']]

# %%
housing_data_condensed = housing_data.dropna()
housing_data_condensed.head()
# Out:
#        price  bedrooms  sqft_living  waterfront  condition
# 1   538000.0         3         2570         0.0          3
# 2   180000.0         2          770         0.0          3
# 3   604000.0         4         1960         0.0          5
# 4   510000.0         3         1680         0.0          3
# 5  1230000.0         4         5420         0.0          3

# %%
sns.heatmap(housing_data)

# %%
sns.set(style="white")

# Create a covariance matrix
corr = housing_data.corr()

# Generate a mask the size of our covariance matrix
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11,9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220,10,as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr,mask=mask,cmap=cmap,vmax=1,center=0,square=True, 
            linewidth=.5, cbar_kws={'shrink': .5})

ax.set_title('Multi-Collinearity of Features')
plt.savefig('correlation1.png')
